# %% [markdown]
# ## Project Name - **Insurance Claim Fraud Detection Project**
#
#
# ##### Name - Aman Mulla.
# ##### Batch - DS2307
# ##### Project Type - EDA and Classification

# %% [markdown]
# # **Project Summary -**
#
# **This project aims to combat insurance fraud by utilizing machine learning on auto insurance data. The dataset encompasses various customer and policy details alongside accident specifics to predict fraudulent insurance claims. With 39 independent variables including customer demographics, policy attributes, accident details, and financial implications, the goal is to create a predictive model. Factors such as policy tenure, age, claim specifics, and incident characteristics will be analyzed to ascertain patterns indicative of fraudulent claims. Machine learning algorithms will be employed to train a model capable of differentiating between genuine and fraudulent claims. By leveraging features like incident severity, property damage, and claim amounts, the model aims to provide insurers with a predictive tool to assess the likelihood of fraud. Ultimately, this project seeks to empower the auto insurance industry with a predictive solution to proactively identify and address potentially fraudulent claims, thereby curbing losses and enhancing the efficiency of claim processing.**
#
# Varibales in Dataset:
#
# 1. **Months_as_customer:** Duration of patronage
# 2. **Age:** Customer's age
# 3. **Policy_number:** Unique ID for customer tracking
# 4. **Policy_bind_date:** Date of insurance proposal acceptance
# 5. **Policy_state:** State-specific insurance policy details
# 6. **Policy_csl:** Combined Single Limit
# 7. **Policy_deductible:** Customer's responsibility for loss payment
# 8. **Policy_annual_premium:** Yearly premium payable by the policyholder
# 9. **Umbrella_limit:** Additional coverage beyond existing policies
# 10. **Insured_zip:** Insurance purchase zip code
# 11. **Insured_sex:** Customer's gender
# 12. **Insured_education_level:** Customer's education level
# 13. **Insured_occupation:** Customer's occupation
# 14. **Insured_hobbies:** Customer's leisure activities
# 15. **Insured_relationship:** Customer's relationship status
# 16. **Capital-gains:** Profits from insurance premium
# 17. **Capital-loss:** Losses from insurance claims
# 18. **Incident_date:** Date of filed claims
# 19. **Incident_type:** Type of claim/vehicle damage
# 20. **Collision_type:** Area of vehicle damage
# 21. Incident_severity:** Extent of damage
# 22. **Authorities_contacted: Government agencies contacted post-accident
# 23. **Incident_state:** State of the accident
# 24. **Incident_city:** City of the accident
# 25. **Incident_location:** Location of the accident
# 26. **Incident_hour_of_the_day:** Time of day of the accident
# 27. **Number_of_vehicles_involved:** Count of vehicles in the accident
# 28. **Property_damage:** Property damage status
# 29. **Bodily_injuries:** Injuries sustained
# 30. **Witnesses:** Number of witnesses
# 31. **Police_report_available:** Documentation status of damage report
# 32. **Total_claim_amount:** Financial implications of claims
# 33. **Injury_claim:** Physical injury claim
# 34. **Property_claim:** Property damage claim
# 35. **Vehicle_claim:** Vehicle damage claim
# 36. **Auto_make:** Vehicle make
# 37. **Auto_model:** Vehicle model
# 38. **Auto_year:** Vehicle manufacturing year
# 39. **_c39:** Unspecified feature
# 40. **Fraud_reported:** Target variable indicating fraud status

# %% [markdown]
# # **Problem Statement**
#
# **In the auto insurance industry, detecting fraudulent claims remains a critical challenge. This project addresses this issue by leveraging machine learning to develop a predictive model capable of discerning fraudulent insurance claims from legitimate ones. Using a comprehensive dataset encompassing customer details, policy specifics, accident characteristics, and financial implications, the goal is to create a model that identifies fraudulent behavior. By analyzing factors such as policy tenure, demographics, incident severity, and claim details, the model aims to classify claims as either genuine or fraudulent. The primary objective is to empower insurance providers with a proactive tool that can accurately predict the likelihood of fraud. This solution seeks to enhance fraud detection accuracy, streamline claim processing, and ultimately reduce financial losses incurred due to fraudulent insurance claims within the auto insurance sector.**

# %% [markdown]
# ## Knowing data and variable in dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %%
insurance_data = pd.read_csv('/content/drive/MyDrive/DataSets/Automobile_insurance_fraud.csv')

insurance_data.head(2)
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# 0       466132        MALE                      MD       craft-repair
# 1       468176        MALE                      MD  machine-op-inspct
#
#   insured_hobbies insured_relationship  capital-gains  capital-loss  \
# 0        sleeping              husband          53300             0
# 1         reading       other-relative              0             0
#
#   incident_date             incident_type  collision_type incident_severity  \
# ...

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Will Check for shape of dataset

insurance_data.shape
# Out:
# (1000, 40)

# %% [markdown]
# **Given dataset contain 1000 rows and 40 columns**

# %% [markdown]
# ### Dataset Information

# %%
insurance_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %% [markdown]
# **Dataset Information:**
#
# * The dataset contains 1000 entries. Most columns have non-null values except for the column "_c39," which has no non-null values, signifying it might be empty or irrelevant.
# * Data Types:
#
#     Numeric Data: Several columns, such as 'months_as_customer,' 'age,' 'policy_deductable,' 'umbrella_limit,' etc., contain numerical data (integers or floats).
#
#     Categorical Data: Columns like 'policy_state,' 'insured_sex,' 'insured_education_level,' 'incident_type,' 'collision_type,' 'property_damage,' and others appear to hold categorical information.
#
#      'policy_bind_date' and 'incident_date' are in object format, likely indicating they are stored as strings and might need conversion for date-time analysis.
#
#      'fraud_reported' appears to be the target variable, indicating whether a claim is fraudulent or not

# %% [markdown]
# #### Null Values/ Duplicate Values

# %%
# Will Chek for duplicate values

insurance_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **No any duplicate values present in dataset**

# %% [markdown]
# ### Null Values

# %%
insurance_data.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
plt.figure(figsize=(15,6))

sns.heatmap(insurance_data.isnull())
# Out:
# <Axes: >

# %%
# As per info of dataset, 'policy_bind_date' and 'incident_date' is in object type, will convert it to datetime so we can use for further analysis

insurance_data['policy_bind_date'] = pd.to_datetime(insurance_data['policy_bind_date'])
insurance_data['incident_date'] = pd.to_datetime(insurance_data['incident_date'])

# by observing column 'policy_csl', in this value is splitd using / , will split both values in two differnt column and name it as 'policy_csl_1' and 'policy_csl_2'

insurance_data[['policy_csl_1', 'policy_csl_2']] = insurance_data['policy_csl'].str.split('/', expand = True)


# Will extract Month, Year and day from the datatime dtype columns

insurance_data['policy_bind_day'] = insurance_data['policy_bind_date'].dt.day
insurance_data['policy_bind_month'] = insurance_data['policy_bind_date'].dt.month
insurance_data['policy_bind_year'] = insurance_data['policy_bind_date'].dt.year

insurance_data['incident_day'] = insurance_data['incident_date'].dt.day
insurance_data['incident_month'] = insurance_data['incident_date'].dt.month
insurance_data['incident_year'] = insurance_data['incident_date'].dt.year
# Out:
# <ipython-input-9-4f9da59f6984>:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   insurance_data['policy_bind_date'] = pd.to_datetime(insurance_data['policy_bind_date'])
# <ipython-input-9-4f9da59f6984>:4: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   insurance_data['incident_date'] = pd.to_datetime(insurance_data['incident_date'])

# %%
# Will Drop unnessary columns from datatset

insurance_data.drop(['policy_csl', 'policy_bind_date', 'incident_date','_c39'], inplace = True, axis = 1)

# %%
# Willseperate for numerical and categerica column frommail dataset

categorical_columns = []
numerical_columns = []

for i in insurance_data.columns:
  if insurance_data[i].dtypes == 'object':
    categorical_columns.append(i)
  elif insurance_data[i].dtypes =='float64' or insurance_data[i].dtypes =='int64':
    numerical_columns.append(i)


print(categorical_columns)
print(numerical_columns)
# Out:
# ['policy_state', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'incident_location', 'property_damage', 'police_report_available', 'auto_make', 'auto_model', 'fraud_reported', 'policy_csl_1', 'policy_csl_2']
# ['months_as_customer', 'age', 'policy_number', 'policy_deductable', 'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'capital-gains', 'capital-loss', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_year', 'policy_bind_day', 'policy_bind_month', 'policy_bind_year', 'incident_day', 'incident_month', 'incident_year']

# %%
# Display unique values present inside each categorical column

for i in categorical_columns:
    print(i, ":")
    print(insurance_data[i].unique())
    print("\n")
# Out:
# policy_state :
# ['OH' 'IN' 'IL']
#
#
# insured_sex :
# ['MALE' 'FEMALE']
#
#
# insured_education_level :
# ['MD' 'PhD' 'Associate' 'Masters' 'High School' 'College' 'JD']
#
#
# insured_occupation :
# ['craft-repair' 'machine-op-inspct' 'sales' 'armed-forces' 'tech-support'
#  'prof-specialty' 'other-service' 'priv-house-serv' 'exec-managerial'
#  'protective-serv' 'transport-moving' 'handlers-cleaners' 'adm-clerical'
#  'farming-fishing']
#
#
# insured_hobbies :
# ['sleeping' 'reading' 'board-games' 'bungie-jumping' 'base-jumping' 'golf'
#  'camping' 'dancing' 'skydiving' 'movies' 'hiking' 'yachting' 'paintball'
#  'chess' 'kayaking' 'polo' 'basketball' 'video-games' 'cross-fit'
#  'exercise']
#
#
# insured_relationship :
# ['husband' 'other-relative' 'own-child' 'unmarried' 'wife' 'not-in-family']
#
#
# incident_type :
# ['Single Vehicle Collision' 'Vehicle Theft' 'Multi-vehicle Collision'
#  'Parked Car']
#
#
# collision_type :
# ...

# %% [markdown]
# **From unique values of each categorical columns, we can observe that having "?" in columns like "collision_type", "property_damage" and "police_report_available". As it will not gives correct information about dataset hence will replace this "?" with mode of respective column.**

# %%
# First will replace "?" with NaN and then fill with mode of respective column

insurance_data['collision_type'].replace(' ?', pd.NA, inplace=True)
insurance_data['property_damage'].replace(' ?', pd.NA, inplace=True)
insurance_data['police_report_available'].replace(' ?', pd.NA, inplace=True)

# %%
# Fill NaNs with mode
insurance_data['collision_type'].fillna(insurance_data['collision_type'].mode()[0], inplace=True)
insurance_data['property_damage'].fillna(insurance_data['property_damage'].mode()[0], inplace=True)
insurance_data['police_report_available'].fillna(insurance_data['police_report_available'].mode()[0], inplace=True)

# %%
# again Checking for Null Values

insurance_data.isnull().sum()
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_state                   0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# bodily_injuries                0
# witnesses                      0
# police_report_available        0
# ...

# %% [markdown]
# ### **As we check total 43 columns in dataset, will revisit all columns and drop for unnessary column to avoide confusion in dataset.**
#
# 1. Dropping 'policy_number':
#   It doesn't contribute to understanding data patterns or assist in fraud prediction.'policy_number' serves as a unique identifier, lacking informative value for analysis or modeling.
# 2. Dropping 'incident_location':
#
#   Address details might not directly influence fraud prediction.'incident_location' provides specific addresses or descriptions of incident sites.
# 3. Dropping 'insured_zip':
#
#    ZIP codes, as standalone values, might not directly impact fraud analysis or prediction. 'insured_zip' contains ZIP codes denoting insured individuals' locations.

# %%
insurance_data.drop(['policy_number', 'incident_location', 'insured_zip'], inplace = True, axis = 1)

# %%
insurance_data.shape
# Out:
# (1000, 41)

# %% [markdown]
# ### **Dataset Description:**

# %%
insurance_data.describe().T
# Out:
#                               count          mean           std         min  \
# months_as_customer           1000.0  2.039540e+02  1.151132e+02        0.00
# age                          1000.0  3.894800e+01  9.140287e+00       19.00
# policy_deductable            1000.0  1.136000e+03  6.118647e+02      500.00
# policy_annual_premium        1000.0  1.256406e+03  2.441674e+02      433.33
# umbrella_limit               1000.0  1.101000e+06  2.297407e+06 -1000000.00
# capital-gains                1000.0  2.512610e+04  2.787219e+04        0.00
# capital-loss                 1000.0 -2.679370e+04  2.810410e+04  -111100.00
# incident_hour_of_the_day     1000.0  1.164400e+01  6.951373e+00        0.00
# number_of_vehicles_involved  1000.0  1.839000e+00  1.018880e+00        1.00
# bodily_injuries              1000.0  9.920000e-01  8.201272e-01        0.00
# witnesses                    1000.0  1.487000e+00  1.111335e+00        0.00
# ...

# %% [markdown]
# * Months_as_customer: Varied customer loyalty (Avg: 204 months, SD: 115).
# * Age: Diverse age range (Avg: 39 years, SD: 9.14, Range: 19-64).
# * Policy_deductable: Wide deductible options (Avg: $1,136, SD: $612, Range: $500-$2,000).
# * Policy_annual_premium: Varying premiums (Avg: $1,256, SD: $244, Range: $433.33-$2,047.59).
# * Umbrella_limit: Diverse coverage (Avg: $1,101,000, SD: $2,297,407, Range: negative to $10,000,000).
# * Capital-gains: Varying gains (Avg: $25,126, SD: $27,872, Range: $0-$100,500).
# * Capital-loss: Varied losses (Avg: -$26,793, SD: $28,104, Range: -$111,100 to $0).
# * Incident_hour_of_the_day: Even distribution (Avg: 11.64, SD: 6.95, Range: 0-23).
# * Number_of_vehicles_involved: Average involvement of 1.84 vehicles (SD: 1.02, Range: 1-4).
# * Bodily_injuries: Average injuries around 0.99 (SD: 0.82, Range: 0-2).
# * Witnesses: Around 1.49 witnesses per incident (SD: 1.11, Range: 0-3).
# * Total_claim_amount: Varied claims (Avg: $52,762, SD: $26,401, Range: $100-$114,920).
# * Injury_claim: Diverse injury expenses (Avg: $7,433, SD: $4,881, Range: $0-$21,450).
# * Property_claim: Varied property damage costs (Avg: $7,400, SD: $4,825, Range: $0-$23,670).
# * Vehicle_claim: Diverse repair costs (Avg: $37,929, SD: $18,886, Range: $70-$79,560).
# * Auto_year: Narrow vehicle year range (Avg: 2005, SD: 6.01, Range: 1995-2015).
# * Policy_CSL_1 & Policy_CSL_2: Coverage limits for injury and property damage.
# * Policy_bind_day, Policy_bind_month, Policy_bind_year: Policy issuance timeline.
# * Incident_day, Incident_month, Incident_year: Incident occurrence timeline.

# %%
insurance_data['insured_occupation'] = insurance_data['insured_occupation'].astype(str)

insurance_data['insured_hobbies'] = insurance_data['insured_hobbies'].astype(str)

insurance_data['auto_make'] = insurance_data['auto_make'].astype(str)

insurance_data['auto_model'] = insurance_data['auto_model'].astype(str)

# %% [markdown]
# ## ***Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***
#
#
# ### **We have so many column in dataset, so to get details EDA for all columns will use function to get visulization of many charts in one plot.**

# %% [markdown]
# #### Chart - 1
#
# ### **Categorical Varibales distribution**

# %%
columns_to_plot = ['policy_state', 'insured_sex', 'insured_education_level', 'insured_relationship', 'incident_type',
                   'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city',
                   'property_damage', 'police_report_available', 'fraud_reported']

rows = 7
columns = 2
plt.figure(figsize=(15, 30))

for i, column in enumerate(columns_to_plot):
    plt.subplot(rows, columns, i + 1)
    sns.countplot(data=insurance_data, x=column, order=insurance_data[column].value_counts().index)
    plt.title("Countplot for " + column)
    plt.tight_layout()

plt.show()

# %% [markdown]
# **Insighst from Above chart:**
# * **Policy State:**
#
#   'OH': 352 occurrences
#   'IL': 338 occurrences
# 'IN': 310 occurrences
#
# * **Insured Sex:**
#
#   'FEMALE': 537 occurrences
# 'MALE': 463 occurrences
# * **Insured Education Level:**
#
#   'JD': 161 occurrences
# 'High School': 160 occurrences
# 'Associate': 145 occurrences
# 'MD': 144 occurrences
# 'Masters': 143 occurrences
# 'PhD': 125 occurrences
# 'College': 122 occurrences
# * **Insured Relationship:**
#
#  'own-child': 183 occurrences
# 'other-relative': 177 occurrences
# 'not-in-family': 174 occurrences
# 'husband': 170 occurrences
# 'wife': 155 occurrences
# 'unmarried': 141 occurrences
# * **Incident Type:**
#
#  'Multi-vehicle Collision': 419 occurrences
# 'Single Vehicle Collision': 403 occurrences
# 'Vehicle Theft': 94 occurrences
# 'Parked Car': 84 occurrences
# * **Collision Type:**
#
#  'Rear Collision': 470 occurrences
# 'Side Collision': 276 occurrences
# 'Front Collision': 254 occurrences
# * **Incident Severity:**
#
#  'Minor Damage': 354 occurrences
# 'Total Loss': 280 occurrences
# 'Major Damage': 276 occurrences
# 'Trivial Damage': 90 occurrences
# * **Authorities Contacted:**
#
#  'Police': 292 occurrences
# 'Fire': 223 occurrences
# 'Other': 198 occurrences
# 'Ambulance': 196 occurrences
# 'None': 91 occurrences
# * **Incident State:**
#
#  'NY': 262 occurrences
# 'SC': 248 occurrences
# 'WV': 217 occurrences
# 'VA' and 'NC': 110 occurrences each
# 'PA': 30 occurrences
# 'OH': 23 occurrences
# * **Incident City:**
#
#  'Springfield': 157 occurrences
# 'Arlington': 152 occurrences
# 'Columbus': 149 occurrences
# 'Northbend': 145 occurrences
# 'Hillsdale': 141 occurrences
# 'Riverwood': 134 occurrences
# 'Northbrook': 122 occurrences
# * **Property Damage:**
#
#  'NO': 698 occurrences
# 'YES': 302 occurrences
# * **Police Report Available:**
#
#  'NO': 686 occurrences
# 'YES': 314 occurrences
# * **Fraud Reported:**
#
#  'N' (No): 753 occurrences
# 'Y' (Yes): 247 occurrences

# %% [markdown]
# #### Chart - 2
#
# ### **Numerical Varibales distribution**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

columns_to_plot = ['age', 'umbrella_limit', 'incident_hour_of_the_day', 'auto_year', 'policy_bind_day', 'policy_bind_month',
                   'policy_bind_year', 'incident_day', 'incident_month']

rows = 10
columns = 1
plt.figure(figsize=(14, 50))

for i in range(len(columns_to_plot)):
    plt.subplot(rows, columns, i + 1)
    sns.histplot(insurance_data[columns_to_plot[i]], kde=True, bins=20)
    plt.title("Histogram for " + columns_to_plot[i])
    plt.tight_layout()

plt.show()

# %% [markdown]
# **Insights from above chart:**
#
# * **Age:**
#
#  Most frequent age: 43 (49 occurrences).
# Other common ages: 39 (48), 41 (45), 34 (44), 38 (42), and 30 (42).
# Least frequent ages: 64 and 63 (only 2 occurrences each).
# * **Umbrella Limit:**
#
#  11 unique values observed.
# Most frequent limit: 0 (798 occurrences).
# Other frequent limits: 6000000 (57), 5000000 (46), 4000000 (39)
# Least frequent limit: -1000000 (1 occurrence).
# * **Incident Hour of the Day:**
#
#  Most frequent hour: 17 (54 occurrences).
# Other common hours: 3 (53), 0 (52), 23 (51)
# Least frequent hour: 1 (29 occurrences).
# * **Auto Year:**
#
#  Most frequent year: 1995 (56 occurrences).
# Other common years: 1999 (55), 2005 (54), 2006 (53)
# Least frequent year: 1996 (37 occurrences).
# * **Policy Bind Day:**
#
#  31 unique values representing days of the month.
# Most frequent day: 28 (48 occurrences).
# Other common days: 12 (44), 2 (44)
# Least frequent day: 31 (11 occurrences).
# * **Policy Bind Month:**
#
#  12 unique values representing months.
# Most frequent month: 7 (96 occurrences).
# Other common months: 11 (91), 9 (87),
# Least frequent month: 2 (74 occurrences).
# * **Policy Bind Year:**
#
#  26 unique values representing years.
# Most frequent year: 1991 (55 occurrences).
# Other common years: 2002 (50), 1992 (48)
# Least frequent year: 2015 (3 occurrences).
# * **Incident Day:**
#
#  31 unique values representing days of the month.
# Most frequent day: 7 (48 occurrences).
# Other common days: 12 (44), 2 (44),
# Least frequent day: 31 (11 occurrences).
# * **Incident Month:**
#
#  12 unique values representing months.
# Most frequent month: 1 (365 occurrences).
# Other common months: 2 (312), 8 (39),

# %% [markdown]
# #### Chart - 3
#
# ### **Multi Varibales distribution**

# %%
columns_to_plot = ['total_claim_amount', 'months_as_customer', 'policy_annual_premium', 'capital-gains', 'capital-loss',
                   'bodily_injuries']
rows = 3
columns = 2

plt.figure(figsize = (10, 10))

for i in range(0, len(columns_to_plot)):
    plt.subplot(rows, columns, i+1)
    sns.barplot(x = 'fraud_reported', y = columns_to_plot[i], data = insurance_data)
    plt.title("Fraud Reported by " + columns_to_plot[i])
    plt.tight_layout()

plt.show()

# %% [markdown]
# **Insights from above chart:**
# * **Total Claim Amount:** Fraudulent cases ('Y') exhibit higher average total claim amounts around $60,302.11 compared to non-fraudulent cases ('N') with an average of $50,288.61.
#
# * **Months as Customer:** 'Y' cases show a shorter average customer duration of approximately 208.08 months, while 'N' cases have a slightly longer average duration of about 202.60 months.
#
# * **Policy Annual Premium:** Both 'Y' and 'N' cases have nearly identical average annual premiums, approximately $1,250.24 for 'Y' and $1,258.43 for 'N'.
#
# * **Capital Gains:** Non-fraudulent cases ('N') tend to have higher average capital gains of $1,250.24, while fraudulent cases ('Y') have a lower average of $208.08.
#
# * **Capital Losses:** 'Y' cases tend to exhibit more negative capital losses, averaging around -$27,522.67, whereas 'N' cases have slightly less negative losses, averaging around -$26,554.58.
#
# * **Bodily Injuries:** The average number of bodily injuries is relatively similar, with 'Y' cases at an average of 1.04 and 'N' cases at 0.98.

# %% [markdown]
# #### Chart - 4
#
# ### **Age vs Total Claim Amount**

# %%
plt.figure(figsize = (15,6))
sns.scatterplot(data = insurance_data, x = 'age', y = 'total_claim_amount')
plt.title("Age vs Total Claim Amount")
plt.xlabel("Age")
plt.ylabel("Total Claim Amount")
plt.show()

# %% [markdown]
# **Insights from above chart:**
# * The scatter plot depicting 'age' against 'total_claim_amount' indicates a rather scattered distribution without a distinct correlation between the two variables. While there's a slight inclination for the total claim amount to marginally increase with age, the relationship lacks strength to establish a clear pattern. The data points are widely dispersed across the plot, depicting a lack of a pronounced trend or strong association between a person's age and the claimed amount.

# %% [markdown]
# #### Chart - 5
#
# ### **Months As Customer vs Total Claim Amount**

# %%
plt.figure(figsize = (15,6))
sns.scatterplot(data = insurance_data, x = 'months_as_customer', y = 'total_claim_amount')
plt.title("Months As Customer vs Total Claim Amount")
plt.xlabel("Months As Customer")
plt.ylabel("Total Claim Amount")
plt.show()

# %% [markdown]
# **Insights from above chart:**
# * The relationship depicted in the scatter plot between 'months_as_customer' and 'total_claim_amount' appears to be relatively weak. As the duration of the customer's association with the insurance company increases, there's a subtle inclination for total claim amounts to rise. However, this correlation is not robust. The data points exhibit significant dispersion, showcasing a wide distribution without a clear, prominent trend. In simpler terms, while there's a slight tendency for claim amounts to increase with longer customer relationships, the variability in the data points suggests that the connection is not strongly defined or predictable.

# %% [markdown]
# #### Chart - 6
#
# ### **Policy Annual Premium vs Total Claim Amount**

# %%
plt.figure(figsize = (15,6))
sns.scatterplot(data = insurance_data, x = 'policy_annual_premium', y = 'total_claim_amount')
plt.title("Policy Annual Premium vs Total Claim Amount")
plt.xlabel("Policy Annual Premium")
plt.ylabel("Total Claim Amount")
plt.show()

# %% [markdown]
# **Insights from above Chart:**
# * The scatter plot representing 'policy_annual_premium' against 'total_claim_amount' displays a minimal inclination for total claims to rise with higher policy annual premiums. However, this connection is so feeble that it's improbable to exert any notable influence on total claim amounts. The data points are extensively dispersed across the plot, lacking a discernible trend or substantial correlation between the two variables.

# %% [markdown]
# #### Chart - 7
#
# ### **Policy Annual Premimum vs Total Claim Amount by Fraud Reported**

# %%
plt.figure(figsize = (15,6))
sns.scatterplot(x = 'policy_annual_premium', y = 'total_claim_amount', hue = 'fraud_reported', data = insurance_data)
plt.xlabel("Policy Annual Premimum")
plt.ylabel("Total Claim Amount")
plt.title("Policy Annual Premimum vs Total Claim Amount by Fraud Reported")
plt.show()

# %% [markdown]
# **Insights from above chart:**
#
# * The scatter plot depicting 'policy_annual_premium' against 'total_claim_amount' categorized by 'fraud_reported' reveals distinct patterns. Both 'Y' (fraud reported) and 'N' (no fraud reported) instances are discernible in the dataset based on these variables. However, 'N' instances noticeably outnumber 'Y' instances, indicating a prevalence of non-fraudulent cases for various 'policy_annual_premium' and 'total_claim_amount' combinations.
# * Regarding the 'incident_year' column, it solely consists of the year 2015, lacking variability or meaningful insights. Its singular value doesn't contribute substantially to the analysis and can be removed to simplify the dataset without significant information loss.

# %% [markdown]
# ### **Will Move ahead for Label Encoding**

# %%
# Columns such as 'policy_state', 'insured_sex', 'insured_education_level', 'insured_occupation',
# 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state',
# 'incident_city', 'property_damage', 'police_report_available', 'auto_make', 'auto_model', and 'fraud_reported' contain categorical data,
# it is necessary to convert this data into numerical format.

from sklearn.preprocessing import LabelEncoder

LabelEnco = LabelEncoder()

# so many variables, will define one funcion

columns_to_encode = ['policy_state', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies',
                     'insured_relationship', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted',
                     'incident_state', 'incident_city', 'property_damage', 'police_report_available', 'auto_make',
                     'auto_model', 'fraud_reported']

LabelEnco = LabelEncoder()
for i in columns_to_encode:
    insurance_data[i] = LabelEnco.fit_transform(insurance_data[i])

insurance_data.head()
# Out:
#    months_as_customer  age  policy_state  policy_deductable  \
# 0                 328   48             2               1000
# 1                 228   42             1               2000
# 2                 134   29             2               2000
# 3                 256   41             0               2000
# 4                 228   44             0               1000
#
#    policy_annual_premium  umbrella_limit  insured_sex  \
# 0                1406.91               0            1
# 1                1197.22         5000000            1
# 2                1413.14         5000000            0
# 3                1415.74         6000000            0
# 4                1583.91         6000000            1
#
#    insured_education_level  insured_occupation  insured_hobbies  \
# 0                        4                   2               17
# 1                        4                   6               15
# 2                        6                  11                2
# ...

# %% [markdown]
# #### Outliers Treatment

# %%
numerical_columns = insurance_data[['months_as_customer', 'age', 'policy_deductable', 'policy_annual_premium', 'umbrella_limit',
                     'capital-gains', 'capital-loss', 'incident_hour_of_the_day', 'number_of_vehicles_involved',
                     'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim',
                     'auto_year', 'policy_csl_1', 'policy_csl_2', 'policy_bind_day', 'policy_bind_month', 'policy_bind_year',
                     'incident_day', 'incident_month']]

plt.figure(figsize=(25,20))
graph = 1

for column in numerical_columns:
  if graph<=23:
    plt.subplot(5,5,graph)
    ax=sns.boxplot(data= numerical_columns[column])
    plt.xlabel(column,fontsize=15)
  graph+=1
plt.show()

# %% [markdown]
# **Outliers are present in 'age', 'policy_annual_premium', 'umbrella_limit', 'total_claim_amount', 'property_claim', and 'incident_month' columns.**

# %%
# Will use z-score method for treating outliers

columns_with_outliers = [ 'age', 'policy_annual_premium', 'umbrella_limit', 'total_claim_amount', 'property_claim','incident_month' ]
from scipy import stats

# Define a threshold for the Z-score
z_score_threshold = 3

# Numerical columns are as defined above

# Create a copy of the dataset for outlier treatment
no_outliers = insurance_data.copy()

for col in columns_with_outliers:
    z_scores = stats.zscore(no_outliers[col])
    no_outliers = no_outliers[(z_scores < z_score_threshold) & (z_scores > -z_score_threshold)]

# Display the shape of the dataset after removing outliers
print("Shape of data after outlier removal:", no_outliers.shape)
# Out:
# Shape of data after outlier removal: (989, 41)

# %% [markdown]
# #### Skewness

# %%
numerical_columns = insurance_data[['months_as_customer', 'age', 'policy_deductable', 'policy_annual_premium', 'umbrella_limit',
                     'capital-gains', 'capital-loss', 'incident_hour_of_the_day', 'number_of_vehicles_involved',
                     'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim',
                     'auto_year', 'policy_csl_1', 'policy_csl_2', 'policy_bind_day', 'policy_bind_month', 'policy_bind_year',
                     'incident_day', 'incident_month']]

plt.figure(figsize=(25,20))
graph = 1

for column in numerical_columns:
  if graph<=23:
    plt.subplot(5,5,graph)
    ax=sns.distplot(numerical_columns[column])
    plt.xlabel(column,fontsize=15)
  graph+=1
plt.show()
# Out:
# <ipython-input-32-8e204776efee>:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(numerical_columns[column])
# <ipython-input-32-8e204776efee>:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(numerical_columns[column])
# ...

# %% [markdown]
# **Insights from above chart:**
# * Right-Skewed Distributions: 'months_as_customer', 'age', 'policy_deductable', 'policy_annual_premium', 'umbrella_limit', 'capital-gains', 'number_of_vehicles_involved', 'witnesses', 'injury_claim', 'property_claim', 'policy_csl_1', 'policy_csl_2', 'policy_bind_day', 'policy_bind_year', 'incident_day', 'incident_month'
# * Left-Skewed Distributions: 'capital-loss', 'incident_hour_of_the_day', 'total_claim_amount', 'vehicle_claim', 'auto_year', 'policy_bind_month'
# * Symmetric Distributions: 'bodily_injuries'

# %%
from scipy.stats import yeojohnson

# List of the columns to be transformed
columns_to_transform = ['umbrella_limit', 'policy_csl_2', 'incident_month', 'total_claim_amount', 'vehicle_claim']

# Ensure columns are of numeric type before transformation
no_outliers[columns_to_transform] = no_outliers[columns_to_transform].apply(pd.to_numeric, errors='coerce')

# Reducing skewness using Yeojohnson Transformation
for column in columns_to_transform:
    transformed_data, lambda_value = yeojohnson(no_outliers[column] + 1)
    no_outliers[column] = transformed_data

# Check skewness of updated columns
no_outliers[columns_to_transform].skew()
# Out:
# umbrella_limit       -7.228826
# policy_csl_2          0.112109
# incident_month        0.359760
# total_claim_amount   -0.510494
# vehicle_claim        -0.524314
# dtype: float64

# %%
# Again checking for the skewness after applying transformation
no_outliers[columns_to_transform].skew()
# Out:
# umbrella_limit       -7.228826
# policy_csl_2          0.112109
# incident_month        0.359760
# total_claim_amount   -0.510494
# vehicle_claim        -0.524314
# dtype: float64

# %% [markdown]
# ### Heatmap and Correlation Matrix

# %%
correlation_data = no_outliers

correlation_matrix = correlation_data.corr()

print(correlation_matrix)

plt.figure(figsize=(20,10))

sns.heatmap(correlation_matrix,annot=True)
plt.title('Correlation Map')
plt.show()
# Out:
# <ipython-input-35-3140ce545adc>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = correlation_data.corr()
#                              months_as_customer       age  policy_state  \
# months_as_customer                     1.000000  0.922653     -0.003976
# age                                    0.922653  1.000000     -0.018272
# policy_state                          -0.003976 -0.018272      1.000000
# policy_deductable                      0.028756  0.029087      0.014274
# policy_annual_premium                 -0.004270  0.005300      0.013909
# umbrella_limit                        -0.005259 -0.000759     -0.039651
# insured_sex                            0.057962  0.073497     -0.019292
# insured_education_level               -0.002550  0.000494     -0.034505
# ...

# %% [markdown]
# **Insights from Heatmap:**
#
# * Positive Correlations:
#
#  Slight positive correlations: 'months_as_customer', 'age', 'policy_state', 'policy_deductable', 'insured_sex', 'insured_education_level', 'insured_relationship', 'capital_gains', 'capital_loss', 'incident_hour_of_the_day', 'property_damage', 'witnesses', 'policy_bind_year', 'incident_month', 'auto_year', 'policy_bind_month', 'auto_model', 'policy_csl_1', 'policy_csl_2'
#
#  Moderate positive correlations: 'umbrella_limit', 'insured_hobbies', 'number_of_vehicles_involved', 'bodily_injuries', 'total_claim_amount', 'injury_claim', 'property_claim', 'auto_make', 'policy_bind_day'
#
#  Strong positive correlations: 'incident_state', 'incident_city', 'vehicle_claim'
#
# * Negative Correlations:
#
#  Slight negative correlations: 'insured_occupation', 'police_report_available', 'auto_model', 'policy_csl_1', 'policy_csl_2'
#
#  Moderate negative correlations: 'incident_type', 'collision_type', 'authorities_contacted', 'incident_month', 'policy_bind_year'
#
#  Strong negative correlations: 'incident_severity', 'incident_day'

# %% [markdown]
# ### To check VIF, will define feature and target Variables

# %%
no_outliers.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_state', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_hour_of_the_day', 'number_of_vehicles_involved',
#        'property_damage', 'bodily_injuries', 'witnesses',
#        'police_report_available', 'total_claim_amount', 'injury_claim',
#        'property_claim', 'vehicle_claim', 'auto_make', 'auto_model',
#        'auto_year', 'fraud_reported', 'policy_csl_1', 'policy_csl_2',
#        'policy_bind_day', 'policy_bind_month', 'policy_bind_year',
#        'incident_day', 'incident_month', 'incident_year'],
#       dtype='object')

# %%
x = no_outliers.drop(columns=['fraud_reported'])
y = no_outliers['fraud_reported']

from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor

scalar = StandardScaler()
x_scaled=scalar.fit_transform(x)

# VIF

vif = pd.DataFrame()

vif['vif']=[variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]

vif['features'] = x.columns

vif
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py:1784: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.uncentered_tss
#              vif                     features
# 0       6.891385           months_as_customer
# 1       6.906768                          age
# 2       1.040129                 policy_state
# 3       1.047322            policy_deductable
# 4       1.039531        policy_annual_premium
# 5       1.041220               umbrella_limit
# 6       1.038498                  insured_sex
# 7       1.044715      insured_education_level
# 8       1.016523           insured_occupation
# 9       1.052975              insured_hobbies
# 10      1.053893         insured_relationship
# 11      1.042823                capital-gains
# 12      1.043162                 capital-loss
# 13      5.209667                incident_type
# 14      1.917159               collision_type
# ...

# %% [markdown]
# **'total_claim_amount' feature has highest VIF value amongs all,will drop it and again calculate the VIF valu**

# %%
no_outliers.drop('total_claim_amount', inplace = True, axis = 1)

# %%
# Again Checking for VIF,

x = no_outliers.drop(columns=['fraud_reported'])
y = no_outliers['fraud_reported']

scalar = StandardScaler()
x_scaled=scalar.fit_transform(x)

# VIF

vif = pd.DataFrame()

vif['vif']=[variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]

vif['features'] = x.columns

vif
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py:1784: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.uncentered_tss
#           vif                     features
# 0    6.888565           months_as_customer
# 1    6.906100                          age
# 2    1.040074                 policy_state
# 3    1.046981            policy_deductable
# 4    1.039238        policy_annual_premium
# 5    1.040407               umbrella_limit
# 6    1.034642                  insured_sex
# 7    1.044664      insured_education_level
# 8    1.016034           insured_occupation
# 9    1.051501              insured_hobbies
# 10   1.053816         insured_relationship
# 11   1.042770                capital-gains
# 12   1.043159                 capital-loss
# 13   5.202185                incident_type
# 14   1.699267               collision_type
# 15   1.213152            incident_severity
# ...

# %% [markdown]
# **'policy_csl_2' feature has highest VIF value will drop it and again calculate the VIF values.**

# %%
no_outliers.drop('policy_csl_2', inplace = True, axis = 1)

# %%
# Again Checking for VIF,

x = no_outliers.drop(columns=['fraud_reported'])
y = no_outliers['fraud_reported']

scalar = StandardScaler()
x_scaled=scalar.fit_transform(x)

# VIF

vif = pd.DataFrame()

vif['vif']=[variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]

vif['features'] = x.columns

vif
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py:1784: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.uncentered_tss
#          vif                     features
# 0   6.885898           months_as_customer
# 1   6.903535                          age
# 2   1.038729                 policy_state
# 3   1.046618            policy_deductable
# 4   1.038702        policy_annual_premium
# 5   1.037268               umbrella_limit
# 6   1.029245                  insured_sex
# 7   1.044662      insured_education_level
# 8   1.015991           insured_occupation
# 9   1.049989              insured_hobbies
# 10  1.049508         insured_relationship
# 11  1.042583                capital-gains
# 12  1.043021                 capital-loss
# 13  5.197841                incident_type
# 14  1.699118               collision_type
# 15  1.213099            incident_severity
# 16  1.080061        authorities_contacted
# ...

# %% [markdown]
# **Seems like VIF in range for all columns**

# %%
# Will check for class Inbalnce

x = no_outliers.drop(columns=['fraud_reported'])
y = no_outliers['fraud_reported']

y.value_counts()
# Out:
# 0    746
# 1    243
# Name: fraud_reported, dtype: int64

# %% [markdown]
# ### **There is imbalance in dataset, will use SMOTE method to minimize class imbalnce in target varibale**

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE()
x, y = smote.fit_resample(x,y)

y.value_counts()
# Out:
# 1    746
# 0    746
# Name: fraud_reported, dtype: int64

# %% [markdown]
# ### **All EDA, Feature selection and class imbalance done, will now built ML model**

# %% [markdown]
# ### ML Model - 1
#
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve,roc_auc_score
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import math

# Defining x and y variable

x = no_outliers.drop(columns=['fraud_reported'])
y = no_outliers['fraud_reported']

# splitting data into train and test set.

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=50)

# Transforming data standardization

scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# Fitting linear regressio to training set
log_reg = LogisticRegression()
log_reg.fit(x_train, y_train)

# Predicting on test set results
y_pred = log_reg.predict(x_test)
y_pred

# Evalution Matrix

Accuracy = accuracy_score(y_test, y_pred)*100

Classification_Report = classification_report(y_test, y_pred)

Confusion_Matrix = confusion_matrix(y_test, y_pred)

print("Logistic Regression")
print("Accuracy score:", Accuracy)
print("Classifiction report:\n", Classification_Report)
print("Confusion matrix:\n", Confusion_Matrix)
print('\n')


# Cross Validiation

cv_score = cross_val_score(log_reg, x, y)

print('\n')
print("Cross Validation Scores:", cv_score*100)
print('\n')

# Will move further with hypertuning

# Parameters grid for hyper parameter tuning

param_grid_lr = {
    'penalty': ['l1', 'l2'],
    'C': [0.001, 0.01, 0.1, 1, 10],
    'solver': ['newton-cg', 'lbfgs', 'liblinear'],
    'max_iter': [100, 200, 300, 400, 500]
}

# Using grid search CV for enhancing the model performance
grid_search_cv = GridSearchCV(LogisticRegression(), param_grid=param_grid_lr, cv=5, scoring='accuracy')


# Performing grid search to find the best hyperparameters for the model
grid_search_cv.fit(x_train, y_train)

# Retrieving the best hyperparameters found during grid search
grid_search_cv.best_params_

# Storing the best parameters
best_params = grid_search_cv.best_params_

# Retrieving the best mean cross-validated score achieved during grid search
grid_search_cv.best_score_

print("Best Parameters for hypertuning Parameters :",best_params)
print("Best Score for Logistic Regression after hypertuning model :",grid_search_cv.best_score_*100)
# Out:
# Logistic Regression
# Accuracy score: 76.43097643097643
# Classifiction report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.91      0.86       229
#            1       0.47      0.26      0.34        68
#
#     accuracy                           0.76       297
#    macro avg       0.64      0.59      0.60       297
# weighted avg       0.73      0.76      0.74       297
#
# Confusion matrix:
#  [[209  20]
#  [ 50  18]]
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...

# %% [markdown]
# **Insights from Logistic Regression Model:**
# * Accuracy Score: 76.43%
# * Precision and Recall:
#
#  Precision for class 0: 81%
# Precision for class 1: 47%
# Recall for class 0: 91%
# Recall for class 1: 26%
# F1-score for class 0: 86%
# F1-score for class 1: 34%
#
# * Confusion Matrix:
#
#  True Positives (TP): 209 (Predicted 1, Actual 1)
# True Negatives (TN): 18 (Predicted 0, Actual 0)
# False Positives (FP): 20 (Predicted 1, Actual 0)
# False Negatives (FN): 50 (Predicted 0, Actual 1)
# Shows the count of correct and incorrect predictions.
#
# * Best Parameters:
# C: 1
# Max iterations: 100
# Penalty: L1 (Lasso regularization)
# Solver: 'liblinear'
#
# * Best Score after Hyperparameter Tuning: 77.31%

# %% [markdown]
# ### ML Model - 2
#
# #### K Neighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# Defining x and y variable

x = no_outliers.drop(columns=['fraud_reported'])
y = no_outliers['fraud_reported']

# splitting data into train and test set.

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=100)

# Transforming data standardization

scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# Fitting linear regressio to training set
knn_classifier = KNeighborsClassifier()
knn_classifier.fit(x_train, y_train)

# Predicting on test set results
y_pred = knn_classifier.predict(x_test)
y_pred

# Evalution Matrix

Accuracy = accuracy_score(y_test, y_pred)*100

Classification_Report = classification_report(y_test, y_pred)

Confusion_Matrix = confusion_matrix(y_test, y_pred)

print("K Neighbors Classifier")
print("Accuracy score:", Accuracy)
print("Classifiction report:\n", Classification_Report)
print("Confusion matrix:\n", Confusion_Matrix)
print('\n')


# Cross Validiation

cv_score = cross_val_score(knn_classifier, x, y)

print('\n')
print("Cross Validation Scores:", cv_score*100)
print('\n')

# Will move further with hypertuning

# Parameters grid for hyper parameter tuning

param_grid_knn = {
    'n_neighbors': [5, 7, 9],
    'weights': ['uniform', 'distance'],
    'algorithm': ['ball_tree', 'kd_tree', 'brute'],
    'leaf_size': [20, 25, 30],
    'p': [1, 2]
}

# Using grid search CV for enhancing the model performance
grid_search_cv = GridSearchCV(KNeighborsClassifier(), param_grid=param_grid_knn, cv=5, scoring='accuracy')


# Performing grid search to find the best hyperparameters for the model
grid_search_cv.fit(x_train, y_train)

# Retrieving the best hyperparameters found during grid search
grid_search_cv.best_params_

# Storing the best parameters
best_params = grid_search_cv.best_params_

# Retrieving the best mean cross-validated score achieved during grid search
grid_search_cv.best_score_

print("Best Parameters for hypertuning Parameters :",best_params)
print("Best Score for K Neighbors Classifier after hypertuning model :",grid_search_cv.best_score_*100)
# Out:
# K Neighbors Classifier
# Accuracy score: 75.08417508417509
# Classifiction report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.91      0.85       233
#            1       0.34      0.17      0.23        64
#
#     accuracy                           0.75       297
#    macro avg       0.57      0.54      0.54       297
# weighted avg       0.70      0.75      0.72       297
#
# Confusion matrix:
#  [[212  21]
#  [ 53  11]]
#
#
#
#
# Cross Validation Scores: [69.6969697  67.17171717 71.71717172 70.70707071 70.55837563]
#
#
# Best Parameters for hypertuning Parameters : {'algorithm': 'ball_tree', 'leaf_size': 20, 'n_neighbors': 9, 'p': 1, 'weights': 'uniform'}
# Best Score for K Neighbors Classifier after hypertuning model : 74.42081117714524

# %% [markdown]
# **Insights from K Neighbors Classifier:**
# * The model achieved an accuracy of approximately 75%.
# * Class 0 (likely the majority class): Precision (80%) indicates that among the instances predicted as class 0, 80% were actually class 0. Recall (91%) implies that the model correctly identified 91% of the actual class 0 instances.
# * Class 1 (likely the minority class): Precision (34%) suggests that among instances predicted as class 1, only 34% were actually class 1. Recall (17%) shows that the model captured only 17% of the actual class 1 instances.
# * The weighted average F1-score is around 72%
# * The model's average cross-validation score is around 70%
# * The best cross-validated score after hyperparameter tuning slightly improved to around 74.42%

# %% [markdown]
# ### ML Model - 3
#
# #### SVC

# %%
from sklearn.svm import SVC

# Defining x and y variable

x = no_outliers.drop(columns=['fraud_reported'])
y = no_outliers['fraud_reported']


# splitting data into train and test set.

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=100)

# Transforming data standardization

scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# Fitting linear regressio to training set
svc_classifier = SVC()
svc_classifier.fit(x_train, y_train)

# Predicting on test set results
y_pred = svc_classifier.predict(x_test)
y_pred

# Evalution Matrix

Accuracy = accuracy_score(y_test, y_pred)*100

Classification_Report = classification_report(y_test, y_pred)

Confusion_Matrix = confusion_matrix(y_test, y_pred)

print("SVC classifier")
print("Accuracy score:", Accuracy)
print("Classifiction report:\n", Classification_Report)
print("Confusion matrix:\n", Confusion_Matrix)
print('\n')


# Cross Validiation

cv_score = cross_val_score(svc_classifier, x, y)

print('\n')
print("Cross Validation Scores:", cv_score*100)
print('\n')

# Will move further with hypertuning

# Parameters grid for hyper parameter tuning

param_grid_svc = {
    'C': [0.1, 1, 10],
    'kernel': ['linear'],
    'gamma': ['auto'],
    'degree': [3, 4]
}

# Using grid search CV for enhancing the model performance
grid_search_cv = GridSearchCV(SVC(), param_grid=param_grid_svc, cv=5, scoring='accuracy')


# Performing grid search to find the best hyperparameters for the model
grid_search_cv.fit(x_train, y_train)

# Retrieving the best hyperparameters found during grid search
grid_search_cv.best_params_

# Storing the best parameters
best_params = grid_search_cv.best_params_

# Retrieving the best mean cross-validated score achieved during grid search
grid_search_cv.best_score_

print("Best Parameters for hypertuning Parameters :",best_params)
print("Best Score for SVC Classifier after hypertuning model :",grid_search_cv.best_score_*100)
# Out:
# SVC classifier
# Accuracy score: 78.11447811447812
# Classifiction report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.99      0.88       233
#            1       0.33      0.02      0.03        64
#
#     accuracy                           0.78       297
#    macro avg       0.56      0.50      0.45       297
# weighted avg       0.69      0.78      0.69       297
#
# Confusion matrix:
#  [[231   2]
#  [ 63   1]]
#
#
#
#
# Cross Validation Scores: [75.25252525 75.25252525 75.25252525 75.75757576 75.63451777]
#
#
# Best Parameters for hypertuning Parameters : {'C': 10, 'degree': 3, 'gamma': 'auto', 'kernel': 'linear'}
# Best Score for SVC Classifier after hypertuning model : 76.87623813992286

# %% [markdown]
# **Insights from SVC Model:**
# * Accuracy: 78.11%
# * Precision and Recall: 0.79 for class 0, 0.33 for class 1,0.99 for class 0, 0.02 for class 1.
# * Best Parameters: {'C': 10, 'degree': 3, 'gamma': 'auto', 'kernel': 'linear'}
# * Best Score: 76.88%
# * Hyperparameter tuning was performed, the increase in performance is minimal, suggesting that further feature engineering or resampling techniques might be necessary to improve the model's performance, especially for class 1.

# %% [markdown]
# ### ML Model - 4
#
# #### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# Defining x and y variable

x = no_outliers.drop(columns=['fraud_reported'])
y = no_outliers['fraud_reported']

# splitting data into train and test set.

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=100)

# Transforming data standardization

scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# Fitting linear regressio to training set
Decision_tress = DecisionTreeClassifier()
Decision_tress.fit(x_train, y_train)

# Predicting on test set results
y_pred = Decision_tress.predict(x_test)
y_pred

# Evalution Matrix

Accuracy = accuracy_score(y_test, y_pred)*100

Classification_Report = classification_report(y_test, y_pred)

Confusion_Matrix = confusion_matrix(y_test, y_pred)

print("Decision Tree Classifier")
print("Accuracy score:", Accuracy)
print("Classifiction report:\n", Classification_Report)
print("Confusion matrix:\n", Confusion_Matrix)
print('\n')


# Cross Validiation

cv_score = cross_val_score(Decision_tress, x, y)

print('\n')
print("Cross Validation Scores:", cv_score*100)
print('\n')

# Will move further with hypertuning

# Parameters grid for hyper parameter tuning

param_grid_dt = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2']
}

# Using grid search CV for enhancing the model performance
grid_search_cv = GridSearchCV(DecisionTreeClassifier(), param_grid=param_grid_dt, cv=5, scoring='accuracy')


# Performing grid search to find the best hyperparameters for the model
grid_search_cv.fit(x_train, y_train)

# Retrieving the best hyperparameters found during grid search
grid_search_cv.best_params_

# Storing the best parameters
best_params = grid_search_cv.best_params_

# Retrieving the best mean cross-validated score achieved during grid search
grid_search_cv.best_score_

print("Best Parameters for hypertuning Parameters :",best_params)
print("Best Score for Decision Tree Classifier after hypertuning model :",grid_search_cv.best_score_*100)
# Out:
# Decision Tree Classifier
# Accuracy score: 76.76767676767676
# Classifiction report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85       233
#            1       0.47      0.55      0.50        64
#
#     accuracy                           0.77       297
#    macro avg       0.67      0.69      0.68       297
# weighted avg       0.78      0.77      0.77       297
#
# Confusion matrix:
#  [[193  40]
#  [ 29  35]]
#
#
#
#
# Cross Validation Scores: [76.26262626 75.25252525 72.72727273 76.76767677 80.20304569]
#
#
# Best Parameters for hypertuning Parameters : {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2}
# Best Score for Decision Tree Classifier after hypertuning model : 79.62569075174642

# %% [markdown]
# **Insights from Decision Tree Classifier:**
# * The model achieves an accuracy score of approximately 76.77%
# * Precision for class 0 (non-defaulters) is high (87%), suggesting that when the model predicts a non-defaulter, it is correct 87% of the time.Recall for class 0 (non-defaulters) is 83%, suggesting the model correctly identifies 83% of actual non-defaulters.
# * The F1-score for class 0 (non-defaulters) is 0.85, and for class 1 (defaulters), it is 0.50. It's the harmonic mean of precision and recall, reflecting the model's balance between precision and recall for each class.
# * Cross-validation scores range from approximately 72.73% to 80.20%
# * The hyperparameters for the best-performing model include 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2
# * The best score after hyperparameter tuning is approximately 79.63%

# %% [markdown]
# ### ML Model - 5
#
# #### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# Defining x and y variable

x = no_outliers.drop(columns=['fraud_reported'])
y = no_outliers['fraud_reported']

# splitting data into train and test set.

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=100)

# Transforming data standardization

scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# Fitting linear regressio to training set
rand_forest = RandomForestClassifier()
rand_forest.fit(x_train, y_train)

# Predicting on test set results
y_pred = rand_forest.predict(x_test)
y_pred

# Evalution Matrix

Accuracy = accuracy_score(y_test, y_pred)*100

Classification_Report = classification_report(y_test, y_pred)

Confusion_Matrix = confusion_matrix(y_test, y_pred)

print("Random Forest Classifier")
print("Accuracy score:", Accuracy)
print("Classifiction report:\n", Classification_Report)
print("Confusion matrix:\n", Confusion_Matrix)
print('\n')


# Cross Validiation

cv_score = cross_val_score(rand_forest, x, y)

print('\n')
print("Cross Validation Scores:", cv_score*100)
print('\n')

# Will move further with hypertuning

# Parameters grid for hyper parameter tuning

param_grid_rf = {
    'n_estimators': [50, 100],
    'criterion': ['gini'],
    'max_depth': [10, 15],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'max_features': ['auto']
}


# Using grid search CV for enhancing the model performance
grid_search_cv = GridSearchCV(RandomForestClassifier(), param_grid=param_grid_rf, cv=5, scoring='accuracy')


# Performing grid search to find the best hyperparameters for the model
grid_search_cv.fit(x_train, y_train)

# Retrieving the best hyperparameters found during grid search
grid_search_cv.best_params_

# Storing the best parameters
best_params = grid_search_cv.best_params_

# Retrieving the best mean cross-validated score achieved during grid search
grid_search_cv.best_score_

print("Best Parameters for hypertuning Parameters :",best_params)
print("Best Score for Random Forest Classifier after hypertuning model :",grid_search_cv.best_score_*100)
# Out:
# Random Forest Classifier
# Accuracy score: 79.7979797979798
# Classifiction report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.94      0.88       233
#            1       0.57      0.27      0.36        64
#
#     accuracy                           0.80       297
#    macro avg       0.70      0.60      0.62       297
# weighted avg       0.77      0.80      0.77       297
#
# Confusion matrix:
#  [[220  13]
#  [ 47  17]]
#
#
#
#
# Cross Validation Scores: [79.29292929 76.26262626 73.23232323 77.27272727 79.69543147]
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# ...

# %% [markdown]
# **Insights from Random Forest Classifier:**
# * The model achieves an accuracy of approximately 79.8%
# * Precision for class 0 (non-default) is high at 82%, suggesting a good proportion of true predictions among the predicted defaults.Recall for class 0 is high (94%), indicating the model's ability to identify actual non-default cases.
# * There are 233 true non-default cases, out of which 220 are correctly predicted, and 13 are falsely predicted as defaults.Only 64 true default cases are identified, while 47 defaults are incorrectly classified as non-defaults.
# * The scores range between approximately 73.2% and 79.7%
# * Best parameters after hyperparameter tuning are identified as:
# criterion: 'gini'
# max_depth: 10
# max_features: 'auto'
# min_samples_leaf: 1
# min_samples_split: 2
# n_estimators: 50
# * The best score achieved after hyperparameter tuning is around 78.32%

# %% [markdown]
# ### ML Model - 6
#
# #### Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Defining x and y variable

x = no_outliers.drop(columns=['fraud_reported'])
y = no_outliers['fraud_reported']

# splitting data into train and test set.

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=100)

# Transforming data standardization

scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# Fitting linear regressio to training set
gboost = GradientBoostingClassifier()
gboost.fit(x_train, y_train)

# Predicting on test set results
y_pred = gboost.predict(x_test)
y_pred

# Evalution Matrix

Accuracy = accuracy_score(y_test, y_pred)*100

Classification_Report = classification_report(y_test, y_pred)

Confusion_Matrix = confusion_matrix(y_test, y_pred)

print("Gradient Boosting Classifier")
print("Accuracy score:", Accuracy)
print("Classifiction report:\n", Classification_Report)
print("Confusion matrix:\n", Confusion_Matrix)
print('\n')


# Cross Validiation

cv_score = cross_val_score(gboost, x, y)

print('\n')
print("Cross Validation Scores:", cv_score*100)
print('\n')

# Will move further with hypertuning

# Parameters grid for hyper parameter tuning

param_grid_gb = {
    'learning_rate': [0.1, 0.05],
    'n_estimators': [100, 200],
    'max_depth': [3, 5],
}

# Using grid search CV for enhancing the model performance
grid_search_cv = GridSearchCV(GradientBoostingClassifier(), param_grid=param_grid_gb, cv=5, scoring='accuracy')


# Performing grid search to find the best hyperparameters for the model
grid_search_cv.fit(x_train, y_train)

# Retrieving the best hyperparameters found during grid search
grid_search_cv.best_params_

# Storing the best parameters
best_params = grid_search_cv.best_params_

# Retrieving the best mean cross-validated score achieved during grid search
grid_search_cv.best_score_

print("Best Parameters for hypertuning Parameters :",best_params)
print("Best Score for Gradient Boosting Classifier after hypertuning model :",grid_search_cv.best_score_*100)
# Out:
# Gradient Boosting Classifier
# Accuracy score: 79.46127946127946
# Classifiction report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.94      0.88       233
#            1       0.55      0.27      0.36        64
#
#     accuracy                           0.79       297
#    macro avg       0.69      0.60      0.62       297
# weighted avg       0.76      0.79      0.77       297
#
# Confusion matrix:
#  [[219  14]
#  [ 47  17]]
#
#
#
#
# Cross Validation Scores: [78.78787879 77.77777778 77.27272727 84.84848485 84.7715736 ]
#
#
# Best Parameters for hypertuning Parameters : {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}
# Best Score for Gradient Boosting Classifier after hypertuning model : 82.07381920550516

# %% [markdown]
# **Insights from Gradient Boosting Classifier:**
# * The model achieves an accuracy of approximately 79.46%.
# * Class 0 (label 0) has better precision, recall, and F1-score compared to Class 1, indicating better performance in predicting Class 0.
# * It indicates the count of true positive, false positive, true negative, and false negative predictions. The model seems better at predicting Class 0 than Class 1.
# * Best Parameters: The best hyperparameters identified after hypertuning are a learning rate of 0.1, a maximum depth of 5, and 200 estimators (trees).
# * The hypertuned model yields an improved accuracy score of approximately 82.07%

# %% [markdown]
# ### ML Model - 7
#
# #### Extra Trees Classifier

# %%
from sklearn.ensemble import ExtraTreesClassifier

# Defining x and y variable

x = no_outliers.drop(columns=['fraud_reported'])
y = no_outliers['fraud_reported']


# splitting data into train and test set.

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=100)

# Transforming data standardization

scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# Fitting linear regressio to training set
extra_tree = ExtraTreesClassifier()
extra_tree.fit(x_train, y_train)

# Predicting on test set results
y_pred = extra_tree.predict(x_test)
y_pred

# Evalution Matrix

Accuracy = accuracy_score(y_test, y_pred)*100

Classification_Report = classification_report(y_test, y_pred)

Confusion_Matrix = confusion_matrix(y_test, y_pred)

print("Extra Trees Classifier")
print("Accuracy score:", Accuracy)
print("Classifiction report:\n", Classification_Report)
print("Confusion matrix:\n", Confusion_Matrix)
print('\n')


# Cross Validiation

cv_score = cross_val_score(extra_tree, x, y)

print('\n')
print("Cross Validation Scores:", cv_score*100)
print('\n')

# Will move further with hypertuning

# Parameters grid for hyper parameter tuning

param_grid_et = {
    'n_estimators': [50, 100],
    'max_depth': [None, 10],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'max_features': ['auto', 'sqrt']
}

# Using grid search CV for enhancing the model performance
grid_search_cv = GridSearchCV(ExtraTreesClassifier(), param_grid=param_grid_et, cv=5, scoring='accuracy')


# Performing grid search to find the best hyperparameters for the model
grid_search_cv.fit(x_train, y_train)

# Retrieving the best hyperparameters found during grid search
grid_search_cv.best_params_

# Storing the best parameters
best_params = grid_search_cv.best_params_

# Retrieving the best mean cross-validated score achieved during grid search
grid_search_cv.best_score_

print("Best Parameters for hypertuning Parameters :",best_params)
print("Best Score for Extra Trees Classifier after hypertuning model :",grid_search_cv.best_score_*100)
# Out:
# Extra Trees Classifier
# Accuracy score: 77.44107744107744
# Classifiction report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.96      0.87       233
#            1       0.40      0.09      0.15        64
#
#     accuracy                           0.77       297
#    macro avg       0.60      0.53      0.51       297
# weighted avg       0.71      0.77      0.72       297
#
# Confusion matrix:
#  [[224   9]
#  [ 58   6]]
#
#
#
#
# Cross Validation Scores: [75.75757576 77.27272727 74.24242424 78.28282828 76.64974619]
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# ...

# %% [markdown]
# **Insights from Extra Trees Classifier:**
# * The model achieved an accuracy of approximately 77.44%.
# * Precision for class 0 (non-target) is 79%, while for class 1 (target) it's 40%. Recall (sensitivity) for class 0 is high (96%) but notably lower for class 1 (9%).
# * The confusion matrix shows 224 true negatives (TN), 9 false positives (FP), 58 false negatives (FN), and 6 true positives (TP).
# * The cross-validation scores range around 75-78%.
# * The best parameters obtained after hyperparameter tuning include max_depth=None, max_features='auto', min_samples_leaf=2, min_samples_split=5, and n_estimators=50
# * The best score after hyperparameter tuning improved slightly to approximately 76.73%

# %% [markdown]
# ---
# # **Conclusion**
# ---
#
# ## **The Random Forest Classifier stands out slightly with the highest accuracy of 79.80% and a better F1-score for class 1 compared to other models.**
#
# * ## Random Forest Classifier:
#   ## Accuracy: 79.80%
#
#   ## F1-score for class 1: 0.36
#
# ### Saving Model 'fraud_reported_best_model'

# %%
# Saving the best model 'Income_best_model'

import pickle

# Save the model to a file
with open('fraud_reported_best_model.pkl', 'wb') as file:
    pickle.dump(rand_forest, file)


# Load the saved model from file
with open('fraud_reported_best_model.pkl', 'rb') as file:
    loaded_model = pickle.load(file)
